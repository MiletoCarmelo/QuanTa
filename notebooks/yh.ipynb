# %%
# set working directory :
import os
pwd = os.getcwd() + "/../"
os.chdir(pwd)

# %%
from financeta.clients.yfinance import YahooFinanceClient
yh = YahooFinanceClient()
df_init = yh.get_price("AAPL", from_date="2025-09-26", to_date="2025-10-04", interval="1m", postclean=True)

df_init.to_pandas()
# Out:
#        timestamp            datetime        open        high         low  \
# 0     1758893400 2025-09-26 15:30:00  254.000000  254.919907  253.779999
# 1     1758893460 2025-09-26 15:31:00  254.610001  254.860001  254.300095
# 2     1758893520 2025-09-26 15:32:00  254.880005  254.978699  254.500000
# 3     1758893580 2025-09-26 15:33:00  254.895203  255.059906  254.550003
# 4     1758893640 2025-09-26 15:34:00  254.843994  254.919998  254.520004
# ...          ...                 ...         ...         ...         ...
# 2333  1759521300 2025-10-03 21:55:00  257.700012  257.959991  257.640015
# 2334  1759521360 2025-10-03 21:56:00  257.695007  257.739990  257.600006
# 2335  1759521420 2025-10-03 21:57:00  257.711304  257.915009  257.660004
# 2336  1759521480 2025-10-03 21:58:00  257.899994  257.970001  257.850006
# 2337  1759521540 2025-10-03 21:59:00  257.859985  258.070007  257.799988
#
#            close   volume
# 0     254.569901  1502884
# 1     254.850006   193864
# 2     254.925003   260898
# 3     254.839996   299410
# 4     254.580002   161740
# ...          ...      ...
# 2333  257.690002   618300
# 2334  257.720001   155320
# 2335  257.903503   231576
# 2336  257.855011   346931
# 2337  258.015015   683893
#
# [2338 rows x 7 columns]

# %%
from financeta.utils.ta import SMA, RSI, MACD, TAClient
indicators = [
    SMA(10),
    SMA(20),
    RSI(14),
    MACD() 
]
ta_client = TAClient()
df = ta_client.calculate_indicators(df_init, indicators)

# %%
from financeta.utils.trace import Candlesticks, Volume, Line

traces = [
    Candlesticks(),
    Line('hl_avg', name='HL Average', color='purple'),
    Volume()
]

# %%
from financeta.clients.chart import ChartClient

chart_client = ChartClient()
chart_client.plot(df, "AAPL", traces=traces, indicators=indicators, theme='professional')

# %%
# test baysian optimization with skopt

import polars as pl
import numpy as np

def backtest_strategy(df: pl.DataFrame, short_window: int, long_window: int, rsi_period: int, stop_loss: float, take_profit: float) -> dict:
    """
    Version avec gestion d'erreurs robuste
    """
    try:
        df = df.clone().drop_nulls()
        
        if len(df) == 0:
            return {
                "total_return": 0.0,
                "sharpe_ratio": 0.0,
                "cagr": 0.0,
                "max_drawdown": 0.0
            }
        
        # Vérifier que les colonnes nécessaires existent
        required_cols = [f'SMA_{short_window}', f'SMA_{long_window}', f'RSI_{rsi_period}', 'close']
        missing_cols = [col for col in required_cols if col not in df.columns]
        
        if missing_cols:
            raise ValueError(f"Colonnes manquantes: {missing_cols}")
        
        # Générer les signaux
        df = df.with_columns([
            pl.when(
                (pl.col(f'SMA_{short_window}') > pl.col(f'SMA_{long_window}')) & 
                (pl.col(f'RSI_{rsi_period}') < 30)
            ).then(1)
            .when(
                (pl.col(f'SMA_{short_window}') < pl.col(f'SMA_{long_window}')) & 
                (pl.col(f'RSI_{rsi_period}') > 70)
            ).then(-1)
            .otherwise(0)
            .alias('signal')
        ])
        
        # Calculer les rendements
        df = df.with_columns([
            pl.col('close').pct_change().alias('price_returns'),
            pl.col('signal').shift(1).fill_null(0).alias('signal_shifted')
        ])
        
        df = df.with_columns([
            (pl.col('price_returns').fill_null(0) * pl.col('signal_shifted') - (stop_loss + take_profit))
            .alias('strategy_returns')
        ])
        
        # Calculer les métriques
        returns = df['strategy_returns'].drop_nulls()
        
        if len(returns) == 0:
            return {
                "total_return": 0.0,
                "sharpe_ratio": 0.0,
                "cagr": 0.0,
                "max_drawdown": 0.0
            }
        
        total_return = returns.sum()
        mean_ret = returns.mean()
        std_ret = returns.std()
        
        # Sharpe ratio
        sharpe_ratio = (mean_ret / std_ret) * np.sqrt(252 * 390) if std_ret and std_ret > 0 else 0.0
        
        # CAGR
        close_first = df['close'][0]
        close_last = df['close'][-1]
        n_periods = len(df)
        cagr = (close_last / close_first) ** (252 * 390 / n_periods) - 1 if n_periods > 0 and close_first > 0 else 0.0
        
        # Max Drawdown
        df = df.with_columns([
            ((1 + pl.col('strategy_returns')).cum_prod()).alias('cum_returns')
        ])
        df = df.with_columns([
            (pl.col('cum_returns') / pl.col('cum_returns').cum_max() - 1).alias('drawdown')
        ])
        
        max_drawdown = df['drawdown'].min() or 0.0
        
        return {
            "total_return": float(total_return),
            "sharpe_ratio": float(sharpe_ratio),
            "cagr": float(cagr),
            "max_drawdown": float(max_drawdown)
        }
        
    except Exception as e:
        print(f"Erreur dans backtest_strategy: {e}")
        return {
            "total_return": 0.0,
            "sharpe_ratio": 0.0,
            "cagr": 0.0,
            "max_drawdown": 0.0
        }

def objective(params):
    short_window, long_window, rsi_period, stop_loss, take_profit = params
    indicators = [
        SMA(short_window),
        SMA(long_window),
        RSI(),
    ]
    ta_client = TAClient()
    df = ta_client.calculate_indicators(df_init, indicators)

    # Backtest the strategy
    metrics = backtest_strategy(df, short_window, long_window, rsi_period, stop_loss, take_profit)
    
    # return minimize negative sharpe ratio
    return -metrics['sharpe_ratio']

# %%
# Configuration JSON avec structure logique
OPTIMIZATION_CONFIG = {
    "indicators": {
        "SMA_short": {
            "class": "SMA",
            "params": {
                "period": {
                    "type": "int",
                    "low": 5,
                    "high": 50
                }
            }
        },
        "SMA_long": {
            "class": "SMA",
            "params": {
                "period": {
                    "type": "int",
                    "low": 20,
                    "high": 200
                }
            }
        },
        "RSI": {
            "class": "RSI",
            "params": {
                "period": {
                    "type": "int",
                    "low": 7,
                    "high": 21
                }
            }
        },
        "BollingerBands": {
            "class": "BollingerBands",
            "params": {
                "period": {
                    "type": "int",
                    "low": 10,
                    "high": 30
                },
                "std_dev": {
                    "type": "float",
                    "low": 1.5,
                    "high": 3.0
                }
            }
        },
        "MACD": {
            "class": "MACD",
            "params": {
                "fast_period": {
                    "type": "int",
                    "low": 8,
                    "high": 16
                },
                "slow_period": {
                    "type": "int",
                    "low": 20,
                    "high": 30
                },
                "signal_period": {
                    "type": "int",
                    "low": 7,
                    "high": 12
                }
            }
        }
    },
    "strategy": {
        "stop_loss": {
            "type": "float",
            "low": 0.001,
            "high": 0.05,
            "log": True
        },
        "take_profit": {
            "type": "float",
            "low": 0.001,
            "high": 0.05,
            "log": True
        },
        "position_size": {
            "type": "float",
            "low": 0.1,
            "high": 1.0
        }
    },
    "constraints": [
        {
            "condition": "SMA_short_period < SMA_long_period"
        },
        {
            "condition": "MACD_fast_period < MACD_slow_period"
        }
    ],
    "optimization": {
        "direction": "maximize",
        "n_trials": 100,
        "n_jobs": 1,
        "timeout": 3600,
        "seed": 42
    }
}

# %%
from financeta.utils.ta import SMA, EMA, RSI, MACD, BollingerBands, ATR, Stochastic

# Mapping des classes d'indicateurs
INDICATOR_CLASSES = {
    'SMA': SMA,
    'EMA': EMA,
    'RSI': RSI,
    'MACD': MACD,
    'BollingerBands': BollingerBands,
    'ATR': ATR,
    'Stochastic': Stochastic,
}

# %%
from typing import Any, Dict, List
import optuna

def suggest_params_from_config(trial: optuna.Trial, config: Dict[str, Any]) -> Dict[str, Any]:
    """
    Génère les suggestions de paramètres pour les indicateurs et la stratégie
    
    Args:
        trial: Objet trial d'Optuna
        config: Configuration JSON complète
    
    Returns:
        Dictionnaire avec 'indicators' et 'strategy'
    """
    params = {
        'indicators': {},
        'strategy': {}
    }
    
    # Suggérer les paramètres des indicateurs
    for indicator_name, indicator_config in config.get("indicators", {}).items():
        params['indicators'][indicator_name] = {}
        
        for param_name, param_config in indicator_config.get("params", {}).items():
            param_type = param_config["type"]
            full_param_name = f"{indicator_name}_{param_name}"
            
            if param_type == "int":
                value = trial.suggest_int(
                    full_param_name,
                    param_config["low"],
                    param_config["high"],
                    step=param_config.get("step", 1)
                )
            elif param_type == "float":
                value = trial.suggest_float(
                    full_param_name,
                    param_config["low"],
                    param_config["high"],
                    log=param_config.get("log", False),
                    step=param_config.get("step", None)
                )
            elif param_type == "categorical":
                value = trial.suggest_categorical(
                    full_param_name,
                    param_config["choices"]
                )
            
            params['indicators'][indicator_name][param_name] = value
    
    # Suggérer les paramètres de stratégie
    for param_name, param_config in config.get("strategy", {}).items():
        param_type = param_config["type"]
        
        if param_type == "int":
            value = trial.suggest_int(
                param_name,
                param_config["low"],
                param_config["high"],
                step=param_config.get("step", 1)
            )
        elif param_type == "float":
            value = trial.suggest_float(
                param_name,
                param_config["low"],
                param_config["high"],
                log=param_config.get("log", False),
                step=param_config.get("step", None)
            )
        elif param_type == "categorical":
            value = trial.suggest_categorical(
                param_name,
                param_config["choices"]
            )
        
        params['strategy'][param_name] = value
    
    return params

def create_indicators_from_params(config: Dict[str, Any], params: Dict[str, Any]) -> List:
    """
    Crée automatiquement les indicateurs depuis les paramètres
    
    Args:
        config: Configuration JSON complète
        params: Paramètres suggérés (avec structure 'indicators' et 'strategy')
    
    Returns:
        Liste des objets indicateurs instanciés
    """
    indicators = []
    
    for indicator_name, indicator_params in params['indicators'].items():
        indicator_config = config['indicators'][indicator_name]
        indicator_class_name = indicator_config['class']
        
        if indicator_class_name not in INDICATOR_CLASSES:
            raise ValueError(f"Indicateur '{indicator_class_name}' non trouvé dans INDICATOR_CLASSES")
        
        indicator_class = INDICATOR_CLASSES[indicator_class_name]
        
        # Instancier l'indicateur avec les paramètres
        try:
            # Essayer d'abord avec kwargs
            indicator = indicator_class(**indicator_params)
        except TypeError:
            # Si ça échoue, essayer avec args positionnels
            indicator = indicator_class(*indicator_params.values())
        
        indicators.append(indicator)
    
    return indicators

def check_constraints(params: Dict[str, Any], constraints: list) -> bool:
    """
    Vérifie si les paramètres respectent les contraintes
    
    Args:
        params: Paramètres suggérés (structure plate pour l'évaluation)
        constraints: Liste des contraintes
    
    Returns:
        True si toutes les contraintes sont respectées
    """
    # Aplatir la structure des params pour l'évaluation
    flat_params = {}
    
    # Ajouter les paramètres d'indicateurs
    for indicator_name, indicator_params in params['indicators'].items():
        for param_name, param_value in indicator_params.items():
            flat_params[f"{indicator_name}_{param_name}"] = param_value
    
    # Ajouter les paramètres de stratégie
    flat_params.update(params['strategy'])
    
    # Vérifier les contraintes
    for constraint in constraints:
        condition = constraint["condition"]
        try:
            if not eval(condition, {}, flat_params):
                return False
        except Exception as e:
            print(f"Erreur lors de l'évaluation de la contrainte '{condition}': {e}")
            return False
    
    return True

# %%
from optuna.samplers import TPESampler
import json

def objective(trial):
    """
    Fonction objectif pour Optuna avec configuration JSON
    """
    config = OPTIMIZATION_CONFIG
    
    # Suggérer les paramètres depuis la config
    params = suggest_params_from_config(trial, config)
    
    # Vérifier les contraintes
    if not check_constraints(params, config.get("constraints", [])):
        return float('-inf')
    
    # Créer automatiquement les indicateurs depuis les paramètres
    indicators = create_indicators_from_params(config, params)
    
    print(indicators)
    
    # Debug: afficher les paramètres testés
    print(f"\nTrial {trial.number}:")
    print(f"  Indicators: {params['indicators']}")
    print(f"  Strategy: {params['strategy']}")
    
    # Calculer les indicateurs sur le DataFrame
    ta_client = TAClient()
    df = ta_client.calculate_indicators(df_init, indicators)
    
    # Backtest de la stratégie
    try:
        # Extraire les paramètres nécessaires pour le backtest
        # Adapter selon votre fonction backtest_strategy
        short_window = params['indicators']['SMA_short']['period']
        long_window = params['indicators']['SMA_long']['period']
        rsi_period = params['indicators']['RSI']['period']
        stop_loss = params['strategy']['stop_loss']
        take_profit = params['strategy']['take_profit']
        
        metrics = backtest_strategy(
            df, 
            short_window,
            long_window,
            rsi_period,
            stop_loss,
            take_profit
        )
        
        # Enregistrer les métriques
        trial.set_user_attr('total_return', metrics['total_return'])
        trial.set_user_attr('cagr', metrics['cagr'])
        trial.set_user_attr('max_drawdown', metrics['max_drawdown'])
        
        return metrics['sharpe_ratio']
    
    except Exception as e:
        print(f"  ❌ Erreur: {e}")
        return float('-inf')

def run_optimization(config: Dict[str, Any]):
    """
    Lance l'optimisation avec la configuration fournie
    """
    opt_config = config["optimization"]
    
    # Afficher la configuration
    print("="*70)
    print("CONFIGURATION DE L'OPTIMISATION")
    print("="*70)
    print(f"\nIndicateurs à optimiser:")
    for ind_name, ind_config in config['indicators'].items():
        print(f"  - {ind_name} ({ind_config['class']}): {list(ind_config['params'].keys())}")
    
    print(f"\nParamètres de stratégie:")
    for param_name in config['strategy'].keys():
        print(f"  - {param_name}")
    
    print(f"\nNombre de trials: {opt_config['n_trials']}")
    print(f"Direction: {opt_config['direction']}")
    print("="*70 + "\n")
    
    study = optuna.create_study(
        direction=opt_config["direction"],
        study_name='trading_strategy_optimization',
        sampler=TPESampler(seed=opt_config.get("seed", None)),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10)
    )
    
    study.optimize(
        objective, 
        n_trials=opt_config["n_trials"],
        n_jobs=opt_config.get("n_jobs", 1),
        show_progress_bar=True,
        timeout=opt_config.get("timeout", None)
    )
    
    print("\n" + "="*70)
    print("RÉSULTATS DE L'OPTIMISATION")
    print("="*70)
    print(f"\n🏆 Meilleur Sharpe Ratio: {study.best_value:.4f}")
    
    print(f"\n📊 Meilleurs paramètres:")
    print("\n  Indicateurs:")
    for key, value in study.best_params.items():
        if any(ind_name in key for ind_name in config['indicators'].keys()):
            print(f"    {key}: {value}")
    
    print("\n  Stratégie:")
    for key, value in study.best_params.items():
        if key in config['strategy'].keys():
            print(f"    {key}: {value}")
    
    print(f"\n💰 Métriques de performance:")
    print(f"    Total Return: {study.best_trial.user_attrs['total_return']:.4f}")
    print(f"    CAGR: {study.best_trial.user_attrs['cagr']:.4f}")
    print(f"    Max Drawdown: {study.best_trial.user_attrs['max_drawdown']:.4f}")
    
    return study


# Lancer l'optimisation
if __name__ == "__main__":
    # Option 1: Utiliser la config directement
    study = run_optimization(OPTIMIZATION_CONFIG)
    
    # Sauvegarder les résultats
    study.trials_dataframe().to_csv('optimization_results.csv', index=False)
    
    # Sauvegarder la meilleure config
    best_config = {
        'indicators': {},
        'strategy': {}
    }
    
    for key, value in study.best_params.items():
        if any(ind_name in key for ind_name in OPTIMIZATION_CONFIG['indicators'].keys()):
            # C'est un paramètre d'indicateur
            for ind_name in OPTIMIZATION_CONFIG['indicators'].keys():
                if key.startswith(ind_name):
                    if ind_name not in best_config['indicators']:
                        best_config['indicators'][ind_name] = {}
                    param_name = key.replace(f"{ind_name}_", "")
                    best_config['indicators'][ind_name][param_name] = value
        else:
            # C'est un paramètre de stratégie
            best_config['strategy'][key] = value
    
    with open('best_config.json', 'w') as f:
        json.dump(best_config, f, indent=4)
    
    print("\n✅ Meilleure configuration sauvegardée dans 'best_config.json'")
# Out:
# [I 2025-10-05 14:59:08,038] A new study created in memory with name: trading_strategy_optimization
# ======================================================================
# CONFIGURATION DE L'OPTIMISATION
# ======================================================================
#
# Indicateurs à optimiser:
#   - SMA_short (SMA): ['period']
#   - SMA_long (SMA): ['period']
#   - RSI (RSI): ['period']
#   - BollingerBands (BollingerBands): ['period', 'std_dev']
#   - MACD (MACD): ['fast_period', 'slow_period', 'signal_period']
#
# Paramètres de stratégie:
#   - stop_loss
#   - take_profit
#   - position_size
#
# Nombre de trials: 100
# Direction: maximize
# ======================================================================
# Best trial: 0. Best value: 0:  12%|█▏        | 12/100 [00:00<00:01, 78.41it/s, 0.19/3600 seconds]
# [<financeta.utils.ta.SMA object at 0x7f07f3734ad0>, <financeta.utils.ta.SMA object at 0x7f07f3734d50>, <financeta.utils.ta.RSI object at 0x7f07f3734490>, <financeta.utils.ta.BollingerBands object at 0x7f07f2178750>, <financeta.utils.ta.MACD object at 0x7f07f2179a90>]
#
# Trial 0:
#   Indicators: {'SMA_short': {'period': 22}, 'SMA_long': {'period': 192}, 'RSI': {'period': 17}, 'BollingerBands': {'period': 22, 'std_dev': 1.7340279606636548}, 'MACD': {'fast_period': 9, 'slow_period': 20, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.010502105436744277, 'take_profit': 0.01595857358814127, 'position_size': 0.1185260448662222}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_22', 'SMA_192', 'RSI_17']
# [I 2025-10-05 14:59:08,050] Trial 0 finished with value: 0.0 and parameters: {'SMA_short_period': 22, 'SMA_long_period': 192, 'RSI_period': 17, 'BollingerBands_period': 22, 'BollingerBands_std_dev': 1.7340279606636548, 'MACD_fast_period': 9, 'MACD_slow_period': 20, 'MACD_signal_period': 12, 'stop_loss': 0.010502105436744277, 'take_profit': 0.01595857358814127, 'position_size': 0.1185260448662222}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f372e550>, <financeta.utils.ta.SMA object at 0x7f07f372fe90>, <financeta.utils.ta.RSI object at 0x7f07f372df90>, <financeta.utils.ta.BollingerBands object at 0x7f07f372eb50>, <financeta.utils.ta.MACD object at 0x7f07f372f2d0>]
#
# Trial 1:
#   Indicators: {'SMA_short': {'period': 49}, 'SMA_long': {'period': 170}, 'RSI': {'period': 10}, 'BollingerBands': {'period': 13, 'std_dev': 1.7751067647801508}, 'MACD': {'fast_period': 10, 'slow_period': 25, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.003124565071260871, 'take_profit': 0.010952662748632562, 'position_size': 0.22554447458683766}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_49', 'SMA_170', 'RSI_10']
# [I 2025-10-05 14:59:08,065] Trial 1 finished with value: 0.0 and parameters: {'SMA_short_period': 49, 'SMA_long_period': 170, 'RSI_period': 10, 'BollingerBands_period': 13, 'BollingerBands_std_dev': 1.7751067647801508, 'MACD_fast_period': 10, 'MACD_slow_period': 25, 'MACD_signal_period': 9, 'stop_loss': 0.003124565071260871, 'take_profit': 0.010952662748632562, 'position_size': 0.22554447458683766}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f372e590>, <financeta.utils.ta.SMA object at 0x7f07f372f050>, <financeta.utils.ta.RSI object at 0x7f07f372e4d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f372efd0>, <financeta.utils.ta.MACD object at 0x7f07f372f690>]
#
# Trial 2:
#   Indicators: {'SMA_short': {'period': 18}, 'SMA_long': {'period': 86}, 'RSI': {'period': 13}, 'BollingerBands': {'period': 26, 'std_dev': 1.7995106732375397}, 'MACD': {'fast_period': 12, 'slow_period': 26, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.010769622478263132, 'take_profit': 0.001948567125127258, 'position_size': 0.1585464336867516}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_18', 'SMA_86', 'RSI_13']
# [I 2025-10-05 14:59:08,080] Trial 2 finished with value: 0.0 and parameters: {'SMA_short_period': 18, 'SMA_long_period': 86, 'RSI_period': 13, 'BollingerBands_period': 26, 'BollingerBands_std_dev': 1.7995106732375397, 'MACD_fast_period': 12, 'MACD_slow_period': 26, 'MACD_signal_period': 7, 'stop_loss': 0.010769622478263132, 'take_profit': 0.001948567125127258, 'position_size': 0.1585464336867516}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07fd3aab10>, <financeta.utils.ta.SMA object at 0x7f07fd3a9090>, <financeta.utils.ta.RSI object at 0x7f07fd3aa590>, <financeta.utils.ta.BollingerBands object at 0x7f07fd3aa710>, <financeta.utils.ta.MACD object at 0x7f07fd3aa410>]
#
# Trial 3:
#   Indicators: {'SMA_short': {'period': 48}, 'SMA_long': {'period': 194}, 'RSI': {'period': 19}, 'BollingerBands': {'period': 16, 'std_dev': 1.6465081710095757}, 'MACD': {'fast_period': 14, 'slow_period': 24, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.0069389014127393955, 'take_profit': 0.0011439974749291274, 'position_size': 0.9183883618709039}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_48', 'SMA_194', 'RSI_19']
# [I 2025-10-05 14:59:08,093] Trial 3 finished with value: 0.0 and parameters: {'SMA_short_period': 48, 'SMA_long_period': 194, 'RSI_period': 19, 'BollingerBands_period': 16, 'BollingerBands_std_dev': 1.6465081710095757, 'MACD_fast_period': 14, 'MACD_slow_period': 24, 'MACD_signal_period': 7, 'stop_loss': 0.0069389014127393955, 'take_profit': 0.0011439974749291274, 'position_size': 0.9183883618709039}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2107f90>, <financeta.utils.ta.SMA object at 0x7f07f22f3990>, <financeta.utils.ta.RSI object at 0x7f07f22f0850>, <financeta.utils.ta.BollingerBands object at 0x7f07f22f37d0>, <financeta.utils.ta.MACD object at 0x7f07f22f1a90>]
#
# Trial 4:
#   Indicators: {'SMA_short': {'period': 16}, 'SMA_long': {'period': 139}, 'RSI': {'period': 11}, 'BollingerBands': {'period': 20, 'std_dev': 2.3200654190149193}, 'MACD': {'fast_period': 9, 'slow_period': 30, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.03946212980759095, 'take_profit': 0.03313483615508949, 'position_size': 0.6381099809299766}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_16', 'SMA_139', 'RSI_11']
# [I 2025-10-05 14:59:08,108] Trial 4 finished with value: 0.0 and parameters: {'SMA_short_period': 16, 'SMA_long_period': 139, 'RSI_period': 11, 'BollingerBands_period': 20, 'BollingerBands_std_dev': 2.3200654190149193, 'MACD_fast_period': 9, 'MACD_slow_period': 30, 'MACD_signal_period': 11, 'stop_loss': 0.03946212980759095, 'take_profit': 0.03313483615508949, 'position_size': 0.6381099809299766}. Best is trial 0 with value: 0.0.
# [I 2025-10-05 14:59:08,114] Trial 5 finished with value: -inf and parameters: {'SMA_short_period': 47, 'SMA_long_period': 36, 'RSI_period': 9, 'BollingerBands_period': 10, 'BollingerBands_std_dev': 1.9879954961448965, 'MACD_fast_period': 11, 'MACD_slow_period': 22, 'MACD_signal_period': 11, 'stop_loss': 0.004037506188440755, 'take_profit': 0.0030012301808980462, 'position_size': 0.5884264748424236}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2dba010>, <financeta.utils.ta.SMA object at 0x7f07f2db9590>, <financeta.utils.ta.RSI object at 0x7f07f2dba0d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f2dbb050>, <financeta.utils.ta.MACD object at 0x7f07f2dba090>]
#
# Trial 6:
#   Indicators: {'SMA_short': {'period': 11}, 'SMA_long': {'period': 165}, 'RSI': {'period': 8}, 'BollingerBands': {'period': 30, 'std_dev': 2.6583671539449862}, 'MACD': {'fast_period': 9, 'slow_period': 20, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.01588288621197004, 'take_profit': 0.017320535358459548, 'position_size': 0.7941433120173511}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_11', 'SMA_165', 'RSI_8']
# [I 2025-10-05 14:59:08,126] Trial 6 finished with value: 0.0 and parameters: {'SMA_short_period': 11, 'SMA_long_period': 165, 'RSI_period': 8, 'BollingerBands_period': 30, 'BollingerBands_std_dev': 2.6583671539449862, 'MACD_fast_period': 9, 'MACD_slow_period': 20, 'MACD_signal_period': 11, 'stop_loss': 0.01588288621197004, 'take_profit': 0.017320535358459548, 'position_size': 0.7941433120173511}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2dbaf50>, <financeta.utils.ta.SMA object at 0x7f07f2db8810>, <financeta.utils.ta.RSI object at 0x7f07f2db8c10>, <financeta.utils.ta.BollingerBands object at 0x7f07f2db9110>, <financeta.utils.ta.MACD object at 0x7f07f2dba690>]
#
# Trial 7:
#   Indicators: {'SMA_short': {'period': 8}, 'SMA_long': {'period': 84}, 'RSI': {'period': 8}, 'BollingerBands': {'period': 28, 'std_dev': 2.4349471902413367}, 'MACD': {'fast_period': 10, 'slow_period': 20, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.003568426123255422, 'take_profit': 0.01736117089039329, 'position_size': 0.6738017242196918}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_8', 'SMA_84', 'RSI_8']
# [I 2025-10-05 14:59:08,139] Trial 7 finished with value: 0.0 and parameters: {'SMA_short_period': 8, 'SMA_long_period': 84, 'RSI_period': 8, 'BollingerBands_period': 28, 'BollingerBands_std_dev': 2.4349471902413367, 'MACD_fast_period': 10, 'MACD_slow_period': 20, 'MACD_signal_period': 8, 'stop_loss': 0.003568426123255422, 'take_profit': 0.01736117089039329, 'position_size': 0.6738017242196918}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2c4c050>, <financeta.utils.ta.SMA object at 0x7f07f2c4d750>, <financeta.utils.ta.RSI object at 0x7f07f2c4d710>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c4e490>, <financeta.utils.ta.MACD object at 0x7f07f2c4d310>]
#
# Trial 8:
#   Indicators: {'SMA_short': {'period': 45}, 'SMA_long': {'period': 105}, 'RSI': {'period': 8}, 'BollingerBands': {'period': 24, 'std_dev': 2.641177572925346}, 'MACD': {'fast_period': 13, 'slow_period': 28, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.0077287168618517844, 'take_profit': 0.005325732706437205, 'position_size': 0.12287721406968567}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_45', 'SMA_105', 'RSI_8']
# [I 2025-10-05 14:59:08,150] Trial 8 finished with value: 0.0 and parameters: {'SMA_short_period': 45, 'SMA_long_period': 105, 'RSI_period': 8, 'BollingerBands_period': 24, 'BollingerBands_std_dev': 2.641177572925346, 'MACD_fast_period': 13, 'MACD_slow_period': 28, 'MACD_signal_period': 9, 'stop_loss': 0.0077287168618517844, 'take_profit': 0.005325732706437205, 'position_size': 0.12287721406968567}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2c4ef10>, <financeta.utils.ta.SMA object at 0x7f07f2c4e190>, <financeta.utils.ta.RSI object at 0x7f07f2c4da90>, <financeta.utils.ta.BollingerBands object at 0x7f07fd34b050>, <financeta.utils.ta.MACD object at 0x7f07fd34aad0>]
#
# Trial 9:
#   Indicators: {'SMA_short': {'period': 9}, 'SMA_long': {'period': 25}, 'RSI': {'period': 16}, 'BollingerBands': {'period': 16, 'std_dev': 2.262856036747054}, 'MACD': {'fast_period': 16, 'slow_period': 22, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.019215811115723028, 'take_profit': 0.0024474916579073796, 'position_size': 0.1692819188459137}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_9', 'SMA_25', 'RSI_16']
# [I 2025-10-05 14:59:08,163] Trial 9 finished with value: 0.0 and parameters: {'SMA_short_period': 9, 'SMA_long_period': 25, 'RSI_period': 16, 'BollingerBands_period': 16, 'BollingerBands_std_dev': 2.262856036747054, 'MACD_fast_period': 16, 'MACD_slow_period': 22, 'MACD_signal_period': 9, 'stop_loss': 0.019215811115723028, 'take_profit': 0.0024474916579073796, 'position_size': 0.1692819188459137}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2bf5210>, <financeta.utils.ta.SMA object at 0x7f07f214ed50>, <financeta.utils.ta.RSI object at 0x7f07f214c890>, <financeta.utils.ta.BollingerBands object at 0x7f07f214fc90>, <financeta.utils.ta.MACD object at 0x7f07f214d2d0>]
#
# Trial 10:
#   Indicators: {'SMA_short': {'period': 30}, 'SMA_long': {'period': 143}, 'RSI': {'period': 21}, 'BollingerBands': {'period': 22, 'std_dev': 1.5230516059921564}, 'MACD': {'fast_period': 8, 'slow_period': 23, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.0014613257873284599, 'take_profit': 0.048528224494085545, 'position_size': 0.35268485881573375}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_30', 'SMA_143', 'RSI_21']
# [I 2025-10-05 14:59:08,192] Trial 10 finished with value: 0.0 and parameters: {'SMA_short_period': 30, 'SMA_long_period': 143, 'RSI_period': 21, 'BollingerBands_period': 22, 'BollingerBands_std_dev': 1.5230516059921564, 'MACD_fast_period': 8, 'MACD_slow_period': 23, 'MACD_signal_period': 12, 'stop_loss': 0.0014613257873284599, 'take_profit': 0.048528224494085545, 'position_size': 0.35268485881573375}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07fd39e8d0>, <financeta.utils.ta.SMA object at 0x7f07f2b85210>, <financeta.utils.ta.RSI object at 0x7f07f2b85a90>, <financeta.utils.ta.BollingerBands object at 0x7f07f2b86750>, <financeta.utils.ta.MACD object at 0x7f07f2b87ad0>]
#
# Trial 11:
#   Indicators: {'SMA_short': {'period': 32}, 'SMA_long': {'period': 192}, 'RSI': {'period': 15}, 'BollingerBands': {'period': 10, 'std_dev': 1.9600051395039788}, 'MACD': {'fast_period': 10, 'slow_period': 26, 'signal_period': 10}}
#   Strategy: {'stop_loss': 0.001493239684269974, 'take_profit': 0.010156910995341944, 'position_size': 0.3549516648714971}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_32', 'SMA_192', 'RSI_15']
# [I 2025-10-05 14:59:08,224] Trial 11 finished with value: 0.0 and parameters: {'SMA_short_period': 32, 'SMA_long_period': 192, 'RSI_period': 15, 'BollingerBands_period': 10, 'BollingerBands_std_dev': 1.9600051395039788, 'MACD_fast_period': 10, 'MACD_slow_period': 26, 'MACD_signal_period': 10, 'stop_loss': 0.001493239684269974, 'take_profit': 0.010156910995341944, 'position_size': 0.3549516648714971}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f214cf10>, <financeta.utils.ta.SMA object at 0x7f07f214ce90>, <financeta.utils.ta.RSI object at 0x7f07f2bbe950>, <financeta.utils.ta.BollingerBands object at 0x7f07f2bbe350>, <financeta.utils.ta.MACD object at 0x7f07f2bbcb90>]
#
# Trial 12:
#   Indicators: {'SMA_short': {'period': 36}, 'SMA_long': {'period': 162}, 'RSI': {'period': 17}, 'BollingerBands': {'period': 17, 'std_dev': 2.0056629899946943}, 'MACD': {'fast_period': 8, 'slow_period': 28, 'signal_period': 10}}
#   Strategy: {'stop_loss': 0.0029629666601044143, 'take_profit': 0.008299965366831903, 'position_size': 0.3613660152525639}
# Best trial: 0. Best value: 0:  19%|█▉        | 19/100 [00:00<00:01, 51.22it/s, 0.38/3600 seconds]
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_36', 'SMA_162', 'RSI_17']
# [I 2025-10-05 14:59:08,249] Trial 12 finished with value: 0.0 and parameters: {'SMA_short_period': 36, 'SMA_long_period': 162, 'RSI_period': 17, 'BollingerBands_period': 17, 'BollingerBands_std_dev': 2.0056629899946943, 'MACD_fast_period': 8, 'MACD_slow_period': 28, 'MACD_signal_period': 10, 'stop_loss': 0.0029629666601044143, 'take_profit': 0.008299965366831903, 'position_size': 0.3613660152525639}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f372c8d0>, <financeta.utils.ta.SMA object at 0x7f07f214c390>, <financeta.utils.ta.RSI object at 0x7f07f2bbf550>, <financeta.utils.ta.BollingerBands object at 0x7f07f2bbf390>, <financeta.utils.ta.MACD object at 0x7f07f2bbd3d0>]
#
# Trial 13:
#   Indicators: {'SMA_short': {'period': 22}, 'SMA_long': {'period': 200}, 'RSI': {'period': 12}, 'BollingerBands': {'period': 13, 'std_dev': 2.948006919098183}, 'MACD': {'fast_period': 11, 'slow_period': 25, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.0024676734116298644, 'take_profit': 0.017364348587507444, 'position_size': 0.26746690877197943}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_22', 'SMA_200', 'RSI_12']
# [I 2025-10-05 14:59:08,279] Trial 13 finished with value: 0.0 and parameters: {'SMA_short_period': 22, 'SMA_long_period': 200, 'RSI_period': 12, 'BollingerBands_period': 13, 'BollingerBands_std_dev': 2.948006919098183, 'MACD_fast_period': 11, 'MACD_slow_period': 25, 'MACD_signal_period': 12, 'stop_loss': 0.0024676734116298644, 'take_profit': 0.017364348587507444, 'position_size': 0.26746690877197943}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2bbd2d0>, <financeta.utils.ta.SMA object at 0x7f07f2178fd0>, <financeta.utils.ta.RSI object at 0x7f07f2d7e8d0>, <financeta.utils.ta.BollingerBands object at 0x7f07fd74bad0>, <financeta.utils.ta.MACD object at 0x7f07f2272fd0>]
#
# Trial 14:
#   Indicators: {'SMA_short': {'period': 39}, 'SMA_long': {'period': 170}, 'RSI': {'period': 18}, 'BollingerBands': {'period': 19, 'std_dev': 1.7638576351618465}, 'MACD': {'fast_period': 10, 'slow_period': 21, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.005663807998386166, 'take_profit': 0.00511241463665301, 'position_size': 0.49299868329244106}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_39', 'SMA_170', 'RSI_18']
# [I 2025-10-05 14:59:08,309] Trial 14 finished with value: 0.0 and parameters: {'SMA_short_period': 39, 'SMA_long_period': 170, 'RSI_period': 18, 'BollingerBands_period': 19, 'BollingerBands_std_dev': 1.7638576351618465, 'MACD_fast_period': 10, 'MACD_slow_period': 21, 'MACD_signal_period': 8, 'stop_loss': 0.005663807998386166, 'take_profit': 0.00511241463665301, 'position_size': 0.49299868329244106}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2dbb1d0>, <financeta.utils.ta.SMA object at 0x7f07f2270410>, <financeta.utils.ta.RSI object at 0x7f07f2b84590>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c4c910>, <financeta.utils.ta.MACD object at 0x7f07f2184690>]
#
# Trial 15:
#   Indicators: {'SMA_short': {'period': 24}, 'SMA_long': {'period': 132}, 'RSI': {'period': 11}, 'BollingerBands': {'period': 23, 'std_dev': 1.5317887054366581}, 'MACD': {'fast_period': 12, 'slow_period': 28, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.03661777161637735, 'take_profit': 0.010829336588126017, 'position_size': 0.2557948355260486}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_24', 'SMA_132', 'RSI_11']
# [I 2025-10-05 14:59:08,333] Trial 15 finished with value: 0.0 and parameters: {'SMA_short_period': 24, 'SMA_long_period': 132, 'RSI_period': 11, 'BollingerBands_period': 23, 'BollingerBands_std_dev': 1.5317887054366581, 'MACD_fast_period': 12, 'MACD_slow_period': 28, 'MACD_signal_period': 9, 'stop_loss': 0.03661777161637735, 'take_profit': 0.010829336588126017, 'position_size': 0.2557948355260486}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f372d4d0>, <financeta.utils.ta.SMA object at 0x7f07f21851d0>, <financeta.utils.ta.RSI object at 0x7f07f21850d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f21876d0>, <financeta.utils.ta.MACD object at 0x7f07f21856d0>]
#
# Trial 16:
#   Indicators: {'SMA_short': {'period': 40}, 'SMA_long': {'period': 174}, 'RSI': {'period': 14}, 'BollingerBands': {'period': 13, 'std_dev': 2.10630154221727}, 'MACD': {'fast_period': 9, 'slow_period': 30, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.016434313900487673, 'take_profit': 0.026414008222462662, 'position_size': 0.4808897649524926}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_40', 'SMA_174', 'RSI_14']
# [I 2025-10-05 14:59:08,361] Trial 16 finished with value: 0.0 and parameters: {'SMA_short_period': 40, 'SMA_long_period': 174, 'RSI_period': 14, 'BollingerBands_period': 13, 'BollingerBands_std_dev': 2.10630154221727, 'MACD_fast_period': 9, 'MACD_slow_period': 30, 'MACD_signal_period': 8, 'stop_loss': 0.016434313900487673, 'take_profit': 0.026414008222462662, 'position_size': 0.4808897649524926}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f220e910>, <financeta.utils.ta.SMA object at 0x7f07f2185f90>, <financeta.utils.ta.RSI object at 0x7f07f2186c90>, <financeta.utils.ta.BollingerBands object at 0x7f07f2186450>, <financeta.utils.ta.MACD object at 0x7f07f2184e90>]
#
# Trial 17:
#   Indicators: {'SMA_short': {'period': 26}, 'SMA_long': {'period': 122}, 'RSI': {'period': 21}, 'BollingerBands': {'period': 13, 'std_dev': 1.8085231157492918}, 'MACD': {'fast_period': 14, 'slow_period': 24, 'signal_period': 10}}
#   Strategy: {'stop_loss': 0.010508720401950528, 'take_profit': 0.005731756136786269, 'position_size': 0.2742860257180693}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_26', 'SMA_122', 'RSI_21']
# [I 2025-10-05 14:59:08,388] Trial 17 finished with value: 0.0 and parameters: {'SMA_short_period': 26, 'SMA_long_period': 122, 'RSI_period': 21, 'BollingerBands_period': 13, 'BollingerBands_std_dev': 1.8085231157492918, 'MACD_fast_period': 14, 'MACD_slow_period': 24, 'MACD_signal_period': 10, 'stop_loss': 0.010508720401950528, 'take_profit': 0.005731756136786269, 'position_size': 0.2742860257180693}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2157c90>, <financeta.utils.ta.SMA object at 0x7f07f2187b50>, <financeta.utils.ta.RSI object at 0x7f07f21849d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f2184d10>, <financeta.utils.ta.MACD object at 0x7f07f2187dd0>]
#
# Trial 18:
#   Indicators: {'SMA_short': {'period': 19}, 'SMA_long': {'period': 156}, 'RSI': {'period': 19}, 'BollingerBands': {'period': 18, 'std_dev': 1.7052973727420278}, 'MACD': {'fast_period': 11, 'slow_period': 26, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.001995468055336585, 'take_profit': 0.0130807819693539, 'position_size': 0.1161956293648935}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_19', 'SMA_156', 'RSI_19']
# [I 2025-10-05 14:59:08,415] Trial 18 finished with value: 0.0 and parameters: {'SMA_short_period': 19, 'SMA_long_period': 156, 'RSI_period': 19, 'BollingerBands_period': 18, 'BollingerBands_std_dev': 1.7052973727420278, 'MACD_fast_period': 11, 'MACD_slow_period': 26, 'MACD_signal_period': 12, 'stop_loss': 0.001995468055336585, 'take_profit': 0.0130807819693539, 'position_size': 0.1161956293648935}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07fd34ad90>, <financeta.utils.ta.SMA object at 0x7f07f223b7d0>, <financeta.utils.ta.RSI object at 0x7f07f2c10990>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c13350>, <financeta.utils.ta.MACD object at 0x7f07f2c12b90>]
#
# Trial 19:
#   Indicators: {'SMA_short': {'period': 33}, 'SMA_long': {'period': 177}, 'RSI': {'period': 10}, 'BollingerBands': {'period': 21, 'std_dev': 2.1449618383745332}, 'MACD': {'fast_period': 8, 'slow_period': 22, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.0010882779648468698, 'take_profit': 0.0291963913968234, 'position_size': 0.45888750186170885}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_33', 'SMA_177', 'RSI_10']
# [I 2025-10-05 14:59:08,447] Trial 19 finished with value: 0.0 and parameters: {'SMA_short_period': 33, 'SMA_long_period': 177, 'RSI_period': 10, 'BollingerBands_period': 21, 'BollingerBands_std_dev': 2.1449618383745332, 'MACD_fast_period': 8, 'MACD_slow_period': 22, 'MACD_signal_period': 11, 'stop_loss': 0.0010882779648468698, 'take_profit': 0.0291963913968234, 'position_size': 0.45888750186170885}. Best is trial 0 with value: 0.0.
# Best trial: 0. Best value: 0:  27%|██▋       | 27/100 [00:00<00:01, 40.34it/s, 0.61/3600 seconds]
# [<financeta.utils.ta.SMA object at 0x7f07f21869d0>, <financeta.utils.ta.SMA object at 0x7f07f2c10a90>, <financeta.utils.ta.RSI object at 0x7f07f2c11350>, <financeta.utils.ta.BollingerBands object at 0x7f07f2ccc910>, <financeta.utils.ta.MACD object at 0x7f07f2ccd290>]
#
# Trial 20:
#   Indicators: {'SMA_short': {'period': 42}, 'SMA_long': {'period': 107}, 'RSI': {'period': 14}, 'BollingerBands': {'period': 25, 'std_dev': 1.8985397396824695}, 'MACD': {'fast_period': 16, 'slow_period': 24, 'signal_period': 10}}
#   Strategy: {'stop_loss': 0.005336982258334335, 'take_profit': 0.0034555596784816337, 'position_size': 0.9993641293753952}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_42', 'SMA_107', 'RSI_14']
# [I 2025-10-05 14:59:08,479] Trial 20 finished with value: 0.0 and parameters: {'SMA_short_period': 42, 'SMA_long_period': 107, 'RSI_period': 14, 'BollingerBands_period': 25, 'BollingerBands_std_dev': 1.8985397396824695, 'MACD_fast_period': 16, 'MACD_slow_period': 24, 'MACD_signal_period': 10, 'stop_loss': 0.005336982258334335, 'take_profit': 0.0034555596784816337, 'position_size': 0.9993641293753952}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2184990>, <financeta.utils.ta.SMA object at 0x7f07f2b86c50>, <financeta.utils.ta.RSI object at 0x7f07f2ccc5d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f2ccc3d0>, <financeta.utils.ta.MACD object at 0x7f07f2ccd950>]
#
# Trial 21:
#   Indicators: {'SMA_short': {'period': 18}, 'SMA_long': {'period': 81}, 'RSI': {'period': 13}, 'BollingerBands': {'period': 26, 'std_dev': 1.8206667364122613}, 'MACD': {'fast_period': 12, 'slow_period': 26, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.009750670362340329, 'take_profit': 0.0011766845074778895, 'position_size': 0.2040128880282683}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_18', 'SMA_81', 'RSI_13']
# [I 2025-10-05 14:59:08,510] Trial 21 finished with value: 0.0 and parameters: {'SMA_short_period': 18, 'SMA_long_period': 81, 'RSI_period': 13, 'BollingerBands_period': 26, 'BollingerBands_std_dev': 1.8206667364122613, 'MACD_fast_period': 12, 'MACD_slow_period': 26, 'MACD_signal_period': 7, 'stop_loss': 0.009750670362340329, 'take_profit': 0.0011766845074778895, 'position_size': 0.2040128880282683}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2186290>, <financeta.utils.ta.SMA object at 0x7f07f211e590>, <financeta.utils.ta.RSI object at 0x7f07fc1c4750>, <financeta.utils.ta.BollingerBands object at 0x7f07fc1c7010>, <financeta.utils.ta.MACD object at 0x7f07fc1c5150>]
#
# Trial 22:
#   Indicators: {'SMA_short': {'period': 13}, 'SMA_long': {'period': 68}, 'RSI': {'period': 13}, 'BollingerBands': {'period': 27, 'std_dev': 1.6434374102629399}, 'MACD': {'fast_period': 12, 'slow_period': 27, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.025631051413890542, 'take_profit': 0.0021695273859936226, 'position_size': 0.18108879710738335}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_13', 'SMA_68', 'RSI_13']
# [I 2025-10-05 14:59:08,537] Trial 22 finished with value: 0.0 and parameters: {'SMA_short_period': 13, 'SMA_long_period': 68, 'RSI_period': 13, 'BollingerBands_period': 27, 'BollingerBands_std_dev': 1.6434374102629399, 'MACD_fast_period': 12, 'MACD_slow_period': 27, 'MACD_signal_period': 7, 'stop_loss': 0.025631051413890542, 'take_profit': 0.0021695273859936226, 'position_size': 0.18108879710738335}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2ba8290>, <financeta.utils.ta.SMA object at 0x7f07f2ba8c10>, <financeta.utils.ta.RSI object at 0x7f07f2ba9c50>, <financeta.utils.ta.BollingerBands object at 0x7f07f2bab890>, <financeta.utils.ta.MACD object at 0x7f07f2babb50>]
#
# Trial 23:
#   Indicators: {'SMA_short': {'period': 5}, 'SMA_long': {'period': 62}, 'RSI': {'period': 16}, 'BollingerBands': {'period': 30, 'std_dev': 2.0879985468656406}, 'MACD': {'fast_period': 13, 'slow_period': 25, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.01176587125921083, 'take_profit': 0.0017359254723401452, 'position_size': 0.10732562599672255}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_5', 'SMA_62', 'RSI_16']
# [I 2025-10-05 14:59:08,568] Trial 23 finished with value: 0.0 and parameters: {'SMA_short_period': 5, 'SMA_long_period': 62, 'RSI_period': 16, 'BollingerBands_period': 30, 'BollingerBands_std_dev': 2.0879985468656406, 'MACD_fast_period': 13, 'MACD_slow_period': 25, 'MACD_signal_period': 8, 'stop_loss': 0.01176587125921083, 'take_profit': 0.0017359254723401452, 'position_size': 0.10732562599672255}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07fd396b10>, <financeta.utils.ta.SMA object at 0x7f07f2186f90>, <financeta.utils.ta.RSI object at 0x7f07f2186850>, <financeta.utils.ta.BollingerBands object at 0x7f07f2184e90>, <financeta.utils.ta.MACD object at 0x7f07f2baba90>]
#
# Trial 24:
#   Indicators: {'SMA_short': {'period': 22}, 'SMA_long': {'period': 94}, 'RSI': {'period': 11}, 'BollingerBands': {'period': 24, 'std_dev': 1.858056697105194}, 'MACD': {'fast_period': 10, 'slow_period': 29, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.005413891739453963, 'take_profit': 0.007370775107581501, 'position_size': 0.21855014375206727}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_22', 'SMA_94', 'RSI_11']
# [I 2025-10-05 14:59:08,598] Trial 24 finished with value: 0.0 and parameters: {'SMA_short_period': 22, 'SMA_long_period': 94, 'RSI_period': 11, 'BollingerBands_period': 24, 'BollingerBands_std_dev': 1.858056697105194, 'MACD_fast_period': 10, 'MACD_slow_period': 29, 'MACD_signal_period': 9, 'stop_loss': 0.005413891739453963, 'take_profit': 0.007370775107581501, 'position_size': 0.21855014375206727}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f372cc10>, <financeta.utils.ta.SMA object at 0x7f07f2c10bd0>, <financeta.utils.ta.RSI object at 0x7f07fd39f010>, <financeta.utils.ta.BollingerBands object at 0x7f07f2bd2810>, <financeta.utils.ta.MACD object at 0x7f07f22783d0>]
#
# Trial 25:
#   Indicators: {'SMA_short': {'period': 28}, 'SMA_long': {'period': 150}, 'RSI': {'period': 7}, 'BollingerBands': {'period': 28, 'std_dev': 1.616698543700881}, 'MACD': {'fast_period': 9, 'slow_period': 27, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.024127762013485488, 'take_profit': 0.004036593306941405, 'position_size': 0.32902354527893707}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_28', 'SMA_150', 'RSI_7']
# [I 2025-10-05 14:59:08,624] Trial 25 finished with value: 0.0 and parameters: {'SMA_short_period': 28, 'SMA_long_period': 150, 'RSI_period': 7, 'BollingerBands_period': 28, 'BollingerBands_std_dev': 1.616698543700881, 'MACD_fast_period': 9, 'MACD_slow_period': 27, 'MACD_signal_period': 7, 'stop_loss': 0.024127762013485488, 'take_profit': 0.004036593306941405, 'position_size': 0.32902354527893707}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f22f1f50>, <financeta.utils.ta.SMA object at 0x7f07f22ba050>, <financeta.utils.ta.RSI object at 0x7f07f22b8110>, <financeta.utils.ta.BollingerBands object at 0x7f07f22b8d90>, <financeta.utils.ta.MACD object at 0x7f07f22b9110>]
#
# Trial 26:
#   Indicators: {'SMA_short': {'period': 15}, 'SMA_long': {'period': 183}, 'RSI': {'period': 15}, 'BollingerBands': {'period': 22, 'std_dev': 1.7348392981665806}, 'MACD': {'fast_period': 11, 'slow_period': 23, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.012854976489213533, 'take_profit': 0.013405927771169852, 'position_size': 0.4110578070715739}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_15', 'SMA_183', 'RSI_15']
# [I 2025-10-05 14:59:08,650] Trial 26 finished with value: 0.0 and parameters: {'SMA_short_period': 15, 'SMA_long_period': 183, 'RSI_period': 15, 'BollingerBands_period': 22, 'BollingerBands_std_dev': 1.7348392981665806, 'MACD_fast_period': 11, 'MACD_slow_period': 23, 'MACD_signal_period': 8, 'stop_loss': 0.012854976489213533, 'take_profit': 0.013405927771169852, 'position_size': 0.4110578070715739}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2bbc190>, <financeta.utils.ta.SMA object at 0x7f07f213e290>, <financeta.utils.ta.RSI object at 0x7f07f213da10>, <financeta.utils.ta.BollingerBands object at 0x7f07f213d650>, <financeta.utils.ta.MACD object at 0x7f07f213e250>]
#
# Trial 27:
#   Indicators: {'SMA_short': {'period': 21}, 'SMA_long': {'period': 124}, 'RSI': {'period': 12}, 'BollingerBands': {'period': 15, 'std_dev': 2.459240523660378}, 'MACD': {'fast_period': 13, 'slow_period': 21, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.008855436320518146, 'take_profit': 0.02220983018069442, 'position_size': 0.2844659179550111}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_21', 'SMA_124', 'RSI_12']
# [I 2025-10-05 14:59:08,677] Trial 27 finished with value: 0.0 and parameters: {'SMA_short_period': 21, 'SMA_long_period': 124, 'RSI_period': 12, 'BollingerBands_period': 15, 'BollingerBands_std_dev': 2.459240523660378, 'MACD_fast_period': 13, 'MACD_slow_period': 21, 'MACD_signal_period': 9, 'stop_loss': 0.008855436320518146, 'take_profit': 0.02220983018069442, 'position_size': 0.2844659179550111}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2bbf8d0>, <financeta.utils.ta.SMA object at 0x7f07f2bbe4d0>, <financeta.utils.ta.RSI object at 0x7f07f2c05a90>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c066d0>, <financeta.utils.ta.MACD object at 0x7f07f2c07450>]
#
# Trial 28:
#   Indicators: {'SMA_short': {'period': 50}, 'SMA_long': {'period': 52}, 'RSI': {'period': 10}, 'BollingerBands': {'period': 20, 'std_dev': 1.5073821965636784}, 'MACD': {'fast_period': 15, 'slow_period': 25, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.004171649682095081, 'take_profit': 0.001558509921249685, 'position_size': 0.18239097241534785}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_50', 'SMA_52', 'RSI_10']
# [I 2025-10-05 14:59:08,707] Trial 28 finished with value: 0.0 and parameters: {'SMA_short_period': 50, 'SMA_long_period': 52, 'RSI_period': 10, 'BollingerBands_period': 20, 'BollingerBands_std_dev': 1.5073821965636784, 'MACD_fast_period': 15, 'MACD_slow_period': 25, 'MACD_signal_period': 11, 'stop_loss': 0.004171649682095081, 'take_profit': 0.001558509921249685, 'position_size': 0.18239097241534785}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2184710>, <financeta.utils.ta.SMA object at 0x7f07f2bbf850>, <financeta.utils.ta.RSI object at 0x7f07f2c06390>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c06050>, <financeta.utils.ta.MACD object at 0x7f07f2c06950>]
#
# Trial 29:
#   Indicators: {'SMA_short': {'period': 26}, 'SMA_long': {'period': 185}, 'RSI': {'period': 19}, 'BollingerBands': {'period': 25, 'std_dev': 1.890846051933411}, 'MACD': {'fast_period': 14, 'slow_period': 23, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.0064612047387698004, 'take_profit': 0.008728609309231894, 'position_size': 0.8511097155848327}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_26', 'SMA_185', 'RSI_19']
# [I 2025-10-05 14:59:08,736] Trial 29 finished with value: 0.0 and parameters: {'SMA_short_period': 26, 'SMA_long_period': 185, 'RSI_period': 19, 'BollingerBands_period': 25, 'BollingerBands_std_dev': 1.890846051933411, 'MACD_fast_period': 14, 'MACD_slow_period': 23, 'MACD_signal_period': 7, 'stop_loss': 0.0064612047387698004, 'take_profit': 0.008728609309231894, 'position_size': 0.8511097155848327}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f22ad490>, <financeta.utils.ta.SMA object at 0x7f07fc1c6290>, <financeta.utils.ta.RSI object at 0x7f07f2267090>, <financeta.utils.ta.BollingerBands object at 0x7f07f2267650>, <financeta.utils.ta.MACD object at 0x7f07f2186d10>]
#
# Trial 30:
#   Indicators: {'SMA_short': {'period': 36}, 'SMA_long': {'period': 199}, 'RSI': {'period': 17}, 'BollingerBands': {'period': 15, 'std_dev': 1.636307798261418}, 'MACD': {'fast_period': 10, 'slow_period': 27, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.014070851856513706, 'take_profit': 0.001010491782680533, 'position_size': 0.1474804075628276}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_36', 'SMA_199', 'RSI_17']
# [I 2025-10-05 14:59:08,764] Trial 30 finished with value: 0.0 and parameters: {'SMA_short_period': 36, 'SMA_long_period': 199, 'RSI_period': 17, 'BollingerBands_period': 15, 'BollingerBands_std_dev': 1.636307798261418, 'MACD_fast_period': 10, 'MACD_slow_period': 27, 'MACD_signal_period': 12, 'stop_loss': 0.014070851856513706, 'take_profit': 0.001010491782680533, 'position_size': 0.1474804075628276}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f214fdd0>, <financeta.utils.ta.SMA object at 0x7f07f2c13310>, <financeta.utils.ta.RSI object at 0x7f07fd397b90>, <financeta.utils.ta.BollingerBands object at 0x7f07f2bdd6d0>, <financeta.utils.ta.MACD object at 0x7f07fc1d7d90>]
#
# Trial 31:
#   Indicators: {'SMA_short': {'period': 47}, 'SMA_long': {'period': 190}, 'RSI': {'period': 20}, 'BollingerBands': {'period': 12, 'std_dev': 1.6922000190721307}, 'MACD': {'fast_period': 14, 'slow_period': 24, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.00756910123327697, 'take_profit': 0.001522897920033327, 'position_size': 0.9836671005768917}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_47', 'SMA_190', 'RSI_20']
# [I 2025-10-05 14:59:08,791] Trial 31 finished with value: 0.0 and parameters: {'SMA_short_period': 47, 'SMA_long_period': 190, 'RSI_period': 20, 'BollingerBands_period': 12, 'BollingerBands_std_dev': 1.6922000190721307, 'MACD_fast_period': 14, 'MACD_slow_period': 24, 'MACD_signal_period': 7, 'stop_loss': 0.00756910123327697, 'take_profit': 0.001522897920033327, 'position_size': 0.9836671005768917}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f22a8f10>, <financeta.utils.ta.SMA object at 0x7f07f223a090>, <financeta.utils.ta.RSI object at 0x7f07f2c91910>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c92c10>, <financeta.utils.ta.MACD object at 0x7f07f2c91890>]
#
# Trial 32:
#   Indicators: {'SMA_short': {'period': 50}, 'SMA_long': {'period': 177}, 'RSI': {'period': 18}, 'BollingerBands': {'period': 19, 'std_dev': 1.9949849550324752}, 'MACD': {'fast_period': 15, 'slow_period': 25, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.004578378314839006, 'take_profit': 0.0011984361248324042, 'position_size': 0.6434401507931614}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_50', 'SMA_177', 'RSI_18']
# [I 2025-10-05 14:59:08,818] Trial 32 finished with value: 0.0 and parameters: {'SMA_short_period': 50, 'SMA_long_period': 177, 'RSI_period': 18, 'BollingerBands_period': 19, 'BollingerBands_std_dev': 1.9949849550324752, 'MACD_fast_period': 15, 'MACD_slow_period': 25, 'MACD_signal_period': 7, 'stop_loss': 0.004578378314839006, 'take_profit': 0.0011984361248324042, 'position_size': 0.6434401507931614}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f227add0>, <financeta.utils.ta.SMA object at 0x7f07f2c91c50>, <financeta.utils.ta.RSI object at 0x7f07f2c924d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c91590>, <financeta.utils.ta.MACD object at 0x7f07f2c90350>]
#
# Trial 33:
#   Indicators: {'SMA_short': {'period': 45}, 'SMA_long': {'period': 146}, 'RSI': {'period': 19}, 'BollingerBands': {'period': 11, 'std_dev': 1.6200318989456002}, 'MACD': {'fast_period': 9, 'slow_period': 21, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.022162546223651446, 'take_profit': 0.0022242572840138392, 'position_size': 0.7252595239878564}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_45', 'SMA_146', 'RSI_19']
# [I 2025-10-05 14:59:08,847] Trial 33 finished with value: 0.0 and parameters: {'SMA_short_period': 45, 'SMA_long_period': 146, 'RSI_period': 19, 'BollingerBands_period': 11, 'BollingerBands_std_dev': 1.6200318989456002, 'MACD_fast_period': 9, 'MACD_slow_period': 21, 'MACD_signal_period': 8, 'stop_loss': 0.022162546223651446, 'take_profit': 0.0022242572840138392, 'position_size': 0.7252595239878564}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f372ec50>, <financeta.utils.ta.SMA object at 0x7f07f372efd0>, <financeta.utils.ta.RSI object at 0x7f07f22ab310>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c91bd0>, <financeta.utils.ta.MACD object at 0x7f07f2c91c10>]
#
# Trial 34:
#   Indicators: {'SMA_short': {'period': 15}, 'SMA_long': {'period': 161}, 'RSI': {'period': 9}, 'BollingerBands': {'period': 16, 'std_dev': 1.7985758026214047}, 'MACD': {'fast_period': 11, 'slow_period': 26, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.049502924354808145, 'take_profit': 0.04040390288315777, 'position_size': 0.5570468868497754}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_15', 'SMA_161', 'RSI_9']
# Best trial: 0. Best value: 0:  41%|████      | 41/100 [00:01<00:01, 37.16it/s, 1.01/3600 seconds]
# [I 2025-10-05 14:59:08,875] Trial 34 finished with value: 0.0 and parameters: {'SMA_short_period': 15, 'SMA_long_period': 161, 'RSI_period': 9, 'BollingerBands_period': 16, 'BollingerBands_std_dev': 1.7985758026214047, 'MACD_fast_period': 11, 'MACD_slow_period': 26, 'MACD_signal_period': 7, 'stop_loss': 0.049502924354808145, 'take_profit': 0.04040390288315777, 'position_size': 0.5570468868497754}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2bbc7d0>, <financeta.utils.ta.SMA object at 0x7f07f22aadd0>, <financeta.utils.ta.RSI object at 0x7f089cd5ac90>, <financeta.utils.ta.BollingerBands object at 0x7f07f2c91ad0>, <financeta.utils.ta.MACD object at 0x7f089cd42d50>]
#
# Trial 35:
#   Indicators: {'SMA_short': {'period': 18}, 'SMA_long': {'period': 94}, 'RSI': {'period': 17}, 'BollingerBands': {'period': 14, 'std_dev': 1.9422239535307237}, 'MACD': {'fast_period': 12, 'slow_period': 20, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.0033066354016627023, 'take_profit': 0.00285282612092938, 'position_size': 0.7594709672330948}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_18', 'SMA_94', 'RSI_17']
# [I 2025-10-05 14:59:08,914] Trial 35 finished with value: 0.0 and parameters: {'SMA_short_period': 18, 'SMA_long_period': 94, 'RSI_period': 17, 'BollingerBands_period': 14, 'BollingerBands_std_dev': 1.9422239535307237, 'MACD_fast_period': 12, 'MACD_slow_period': 20, 'MACD_signal_period': 11, 'stop_loss': 0.0033066354016627023, 'take_profit': 0.00285282612092938, 'position_size': 0.7594709672330948}. Best is trial 0 with value: 0.0.
# [I 2025-10-05 14:59:08,938] Trial 36 finished with value: -inf and parameters: {'SMA_short_period': 46, 'SMA_long_period': 43, 'RSI_period': 15, 'BollingerBands_period': 18, 'BollingerBands_std_dev': 2.205137895412941, 'MACD_fast_period': 13, 'MACD_slow_period': 24, 'MACD_signal_period': 8, 'stop_loss': 0.008136159957325872, 'take_profit': 0.021903637245837205, 'position_size': 0.8711835848438944}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2bc7d50>, <financeta.utils.ta.SMA object at 0x7f07f2bc6b10>, <financeta.utils.ta.RSI object at 0x7f07f2bc4650>, <financeta.utils.ta.BollingerBands object at 0x7f07f2185590>, <financeta.utils.ta.MACD object at 0x7f07f2b8d450>]
#
# Trial 37:
#   Indicators: {'SMA_short': {'period': 12}, 'SMA_long': {'period': 134}, 'RSI': {'period': 20}, 'BollingerBands': {'period': 21, 'std_dev': 1.5856377329275753}, 'MACD': {'fast_period': 15, 'slow_period': 29, 'signal_period': 10}}
#   Strategy: {'stop_loss': 0.01686523896119905, 'take_profit': 0.015717074479883138, 'position_size': 0.92448978834599}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_12', 'SMA_134', 'RSI_20']
# [I 2025-10-05 14:59:08,965] Trial 37 finished with value: 0.0 and parameters: {'SMA_short_period': 12, 'SMA_long_period': 134, 'RSI_period': 20, 'BollingerBands_period': 21, 'BollingerBands_std_dev': 1.5856377329275753, 'MACD_fast_period': 15, 'MACD_slow_period': 29, 'MACD_signal_period': 10, 'stop_loss': 0.01686523896119905, 'take_profit': 0.015717074479883138, 'position_size': 0.92448978834599}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2c05990>, <financeta.utils.ta.SMA object at 0x7f07f2b8c610>, <financeta.utils.ta.RSI object at 0x7f07f2b8fd90>, <financeta.utils.ta.BollingerBands object at 0x7f07f2b8ea90>, <financeta.utils.ta.MACD object at 0x7f07f2b8c710>]
#
# Trial 38:
#   Indicators: {'SMA_short': {'period': 42}, 'SMA_long': {'period': 117}, 'RSI': {'period': 16}, 'BollingerBands': {'period': 29, 'std_dev': 2.3373931967719246}, 'MACD': {'fast_period': 8, 'slow_period': 22, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.006717965827245703, 'take_profit': 0.0018952297256959836, 'position_size': 0.22229626507293782}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_42', 'SMA_117', 'RSI_16']
# [I 2025-10-05 14:59:08,992] Trial 38 finished with value: 0.0 and parameters: {'SMA_short_period': 42, 'SMA_long_period': 117, 'RSI_period': 16, 'BollingerBands_period': 29, 'BollingerBands_std_dev': 2.3373931967719246, 'MACD_fast_period': 8, 'MACD_slow_period': 22, 'MACD_signal_period': 9, 'stop_loss': 0.006717965827245703, 'take_profit': 0.0018952297256959836, 'position_size': 0.22229626507293782}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2284c50>, <financeta.utils.ta.SMA object at 0x7f07f372f710>, <financeta.utils.ta.RSI object at 0x7f07f210c1d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f210ce10>, <financeta.utils.ta.MACD object at 0x7f07f210efd0>]
#
# Trial 39:
#   Indicators: {'SMA_short': {'period': 43}, 'SMA_long': {'period': 189}, 'RSI': {'period': 7}, 'BollingerBands': {'period': 10, 'std_dev': 1.7084600360626188}, 'MACD': {'fast_period': 9, 'slow_period': 20, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.0022310528662762255, 'take_profit': 0.0012706952732026956, 'position_size': 0.30376412336808817}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_43', 'SMA_189', 'RSI_7']
# [I 2025-10-05 14:59:09,019] Trial 39 finished with value: 0.0 and parameters: {'SMA_short_period': 43, 'SMA_long_period': 189, 'RSI_period': 7, 'BollingerBands_period': 10, 'BollingerBands_std_dev': 1.7084600360626188, 'MACD_fast_period': 9, 'MACD_slow_period': 20, 'MACD_signal_period': 7, 'stop_loss': 0.0022310528662762255, 'take_profit': 0.0012706952732026956, 'position_size': 0.30376412336808817}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07bb8783d0>, <financeta.utils.ta.SMA object at 0x7f07bb87a4d0>, <financeta.utils.ta.RSI object at 0x7f07bb879810>, <financeta.utils.ta.BollingerBands object at 0x7f07bb879f90>, <financeta.utils.ta.MACD object at 0x7f07bb879890>]
#
# Trial 40:
#   Indicators: {'SMA_short': {'period': 48}, 'SMA_long': {'period': 80}, 'RSI': {'period': 9}, 'BollingerBands': {'period': 17, 'std_dev': 2.039107139118336}, 'MACD': {'fast_period': 10, 'slow_period': 23, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.011363127572329821, 'take_profit': 0.006207238941871656, 'position_size': 0.6039798255079114}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_48', 'SMA_80', 'RSI_9']
# [I 2025-10-05 14:59:09,048] Trial 40 finished with value: 0.0 and parameters: {'SMA_short_period': 48, 'SMA_long_period': 80, 'RSI_period': 9, 'BollingerBands_period': 17, 'BollingerBands_std_dev': 2.039107139118336, 'MACD_fast_period': 10, 'MACD_slow_period': 23, 'MACD_signal_period': 11, 'stop_loss': 0.011363127572329821, 'take_profit': 0.006207238941871656, 'position_size': 0.6039798255079114}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07bb878790>, <financeta.utils.ta.SMA object at 0x7f07bb879210>, <financeta.utils.ta.RSI object at 0x7f07bb879190>, <financeta.utils.ta.BollingerBands object at 0x7f07bb879090>, <financeta.utils.ta.MACD object at 0x7f07bb878d10>]
#
# Trial 41:
#   Indicators: {'SMA_short': {'period': 16}, 'SMA_long': {'period': 167}, 'RSI': {'period': 11}, 'BollingerBands': {'period': 22, 'std_dev': 2.540363217815449}, 'MACD': {'fast_period': 9, 'slow_period': 29, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.03190248374030395, 'take_profit': 0.03509885924725619, 'position_size': 0.6903656979949587}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_16', 'SMA_167', 'RSI_11']
# [I 2025-10-05 14:59:09,076] Trial 41 finished with value: 0.0 and parameters: {'SMA_short_period': 16, 'SMA_long_period': 167, 'RSI_period': 11, 'BollingerBands_period': 22, 'BollingerBands_std_dev': 2.540363217815449, 'MACD_fast_period': 9, 'MACD_slow_period': 29, 'MACD_signal_period': 12, 'stop_loss': 0.03190248374030395, 'take_profit': 0.03509885924725619, 'position_size': 0.6903656979949587}. Best is trial 0 with value: 0.0.
# Best trial: 0. Best value: 0:  49%|████▉     | 49/100 [00:01<00:01, 36.53it/s, 1.23/3600 seconds]
# ...
# [<financeta.utils.ta.SMA object at 0x7f07c918f950>, <financeta.utils.ta.SMA object at 0x7f07c918d850>, <financeta.utils.ta.RSI object at 0x7f07bb8e7f50>, <financeta.utils.ta.BollingerBands object at 0x7f0791404910>, <financeta.utils.ta.MACD object at 0x7f07c911cc50>]
#
# Trial 87:
#   Indicators: {'SMA_short': {'period': 14}, 'SMA_long': {'period': 179}, 'RSI': {'period': 14}, 'BollingerBands': {'period': 18, 'std_dev': 2.4210461610129514}, 'MACD': {'fast_period': 12, 'slow_period': 24, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.01363683238359066, 'take_profit': 0.029259269814784317, 'position_size': 0.6162625803244639}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_14', 'SMA_179', 'RSI_14']
# [I 2025-10-05 14:59:10,451] Trial 87 finished with value: 0.0 and parameters: {'SMA_short_period': 14, 'SMA_long_period': 179, 'RSI_period': 14, 'BollingerBands_period': 18, 'BollingerBands_std_dev': 2.4210461610129514, 'MACD_fast_period': 12, 'MACD_slow_period': 24, 'MACD_signal_period': 7, 'stop_loss': 0.01363683238359066, 'take_profit': 0.029259269814784317, 'position_size': 0.6162625803244639}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2b84710>, <financeta.utils.ta.SMA object at 0x7f07f2b9f550>, <financeta.utils.ta.RSI object at 0x7f07f2dbc950>, <financeta.utils.ta.BollingerBands object at 0x7f07c911f410>, <financeta.utils.ta.MACD object at 0x7f07c911f850>]
#
# Trial 88:
#   Indicators: {'SMA_short': {'period': 24}, 'SMA_long': {'period': 126}, 'RSI': {'period': 7}, 'BollingerBands': {'period': 30, 'std_dev': 2.162969803181515}, 'MACD': {'fast_period': 9, 'slow_period': 25, 'signal_period': 8}}
#   Strategy: {'stop_loss': 0.023279500941018348, 'take_profit': 0.00204481949283492, 'position_size': 0.7788085039481255}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_24', 'SMA_126', 'RSI_7']
# [I 2025-10-05 14:59:10,483] Trial 88 finished with value: 0.0 and parameters: {'SMA_short_period': 24, 'SMA_long_period': 126, 'RSI_period': 7, 'BollingerBands_period': 30, 'BollingerBands_std_dev': 2.162969803181515, 'MACD_fast_period': 9, 'MACD_slow_period': 25, 'MACD_signal_period': 8, 'stop_loss': 0.023279500941018348, 'take_profit': 0.00204481949283492, 'position_size': 0.7788085039481255}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2c90250>, <financeta.utils.ta.SMA object at 0x7f07f2c101d0>, <financeta.utils.ta.RSI object at 0x7f07c918f9d0>, <financeta.utils.ta.BollingerBands object at 0x7f07f2ba82d0>, <financeta.utils.ta.MACD object at 0x7f07c9190290>]
#
# Trial 89:
#   Indicators: {'SMA_short': {'period': 46}, 'SMA_long': {'period': 136}, 'RSI': {'period': 14}, 'BollingerBands': {'period': 11, 'std_dev': 2.6590351573023217}, 'MACD': {'fast_period': 14, 'slow_period': 21, 'signal_period': 9}}
#   Strategy: {'stop_loss': 0.017091763498461282, 'take_profit': 0.0060570999230241855, 'position_size': 0.2422513452303467}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_46', 'SMA_136', 'RSI_14']
# [I 2025-10-05 14:59:10,517] Trial 89 finished with value: 0.0 and parameters: {'SMA_short_period': 46, 'SMA_long_period': 136, 'RSI_period': 14, 'BollingerBands_period': 11, 'BollingerBands_std_dev': 2.6590351573023217, 'MACD_fast_period': 14, 'MACD_slow_period': 21, 'MACD_signal_period': 9, 'stop_loss': 0.017091763498461282, 'take_profit': 0.0060570999230241855, 'position_size': 0.2422513452303467}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2db8d10>, <financeta.utils.ta.SMA object at 0x7f07bb878e10>, <financeta.utils.ta.RSI object at 0x7f07c9190b10>, <financeta.utils.ta.BollingerBands object at 0x7f07c9190110>, <financeta.utils.ta.MACD object at 0x7f07c9190f10>]
#
# Trial 90:
#   Indicators: {'SMA_short': {'period': 5}, 'SMA_long': {'period': 146}, 'RSI': {'period': 8}, 'BollingerBands': {'period': 23, 'std_dev': 1.7397203609762524}, 'MACD': {'fast_period': 10, 'slow_period': 27, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.043932900975317844, 'take_profit': 0.0017103885759008162, 'position_size': 0.27884832280052974}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_5', 'SMA_146', 'RSI_8']
# [I 2025-10-05 14:59:10,549] Trial 90 finished with value: 0.0 and parameters: {'SMA_short_period': 5, 'SMA_long_period': 146, 'RSI_period': 8, 'BollingerBands_period': 23, 'BollingerBands_std_dev': 1.7397203609762524, 'MACD_fast_period': 10, 'MACD_slow_period': 27, 'MACD_signal_period': 12, 'stop_loss': 0.043932900975317844, 'take_profit': 0.0017103885759008162, 'position_size': 0.27884832280052974}. Best is trial 0 with value: 0.0.
# Best trial: 0. Best value: 0:  98%|█████████▊| 98/100 [00:02<00:00, 31.54it/s, 2.74/3600 seconds]
# [<financeta.utils.ta.SMA object at 0x7f07f21799d0>, <financeta.utils.ta.SMA object at 0x7f07bb8e7090>, <financeta.utils.ta.RSI object at 0x7f07c918c290>, <financeta.utils.ta.BollingerBands object at 0x7f07c91f1a10>, <financeta.utils.ta.MACD object at 0x7f07c9191850>]
#
# Trial 91:
#   Indicators: {'SMA_short': {'period': 49}, 'SMA_long': {'period': 156}, 'RSI': {'period': 20}, 'BollingerBands': {'period': 21, 'std_dev': 1.663311447501595}, 'MACD': {'fast_period': 8, 'slow_period': 23, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.0020742984639249896, 'take_profit': 0.04740033913774456, 'position_size': 0.2002227304825781}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_49', 'SMA_156', 'RSI_20']
# [I 2025-10-05 14:59:10,584] Trial 91 finished with value: 0.0 and parameters: {'SMA_short_period': 49, 'SMA_long_period': 156, 'RSI_period': 20, 'BollingerBands_period': 21, 'BollingerBands_std_dev': 1.663311447501595, 'MACD_fast_period': 8, 'MACD_slow_period': 23, 'MACD_signal_period': 12, 'stop_loss': 0.0020742984639249896, 'take_profit': 0.04740033913774456, 'position_size': 0.2002227304825781}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07c91f2710>, <financeta.utils.ta.SMA object at 0x7f07c91924d0>, <financeta.utils.ta.RSI object at 0x7f07c91925d0>, <financeta.utils.ta.BollingerBands object at 0x7f07c91922d0>, <financeta.utils.ta.MACD object at 0x7f07c9192790>]
#
# Trial 92:
#   Indicators: {'SMA_short': {'period': 30}, 'SMA_long': {'period': 121}, 'RSI': {'period': 21}, 'BollingerBands': {'period': 13, 'std_dev': 1.5381283837459627}, 'MACD': {'fast_period': 8, 'slow_period': 24, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.0013833251354502438, 'take_profit': 0.033875529841988467, 'position_size': 0.1432108859007795}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_30', 'SMA_121', 'RSI_21']
# [I 2025-10-05 14:59:10,617] Trial 92 finished with value: 0.0 and parameters: {'SMA_short_period': 30, 'SMA_long_period': 121, 'RSI_period': 21, 'BollingerBands_period': 13, 'BollingerBands_std_dev': 1.5381283837459627, 'MACD_fast_period': 8, 'MACD_slow_period': 24, 'MACD_signal_period': 12, 'stop_loss': 0.0013833251354502438, 'take_profit': 0.033875529841988467, 'position_size': 0.1432108859007795}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07c91f3550>, <financeta.utils.ta.SMA object at 0x7f07c91902d0>, <financeta.utils.ta.RSI object at 0x7f07c9192d50>, <financeta.utils.ta.BollingerBands object at 0x7f07c91922d0>, <financeta.utils.ta.MACD object at 0x7f07c9191650>]
#
# Trial 93:
#   Indicators: {'SMA_short': {'period': 33}, 'SMA_long': {'period': 49}, 'RSI': {'period': 13}, 'BollingerBands': {'period': 20, 'std_dev': 1.6054417577354962}, 'MACD': {'fast_period': 9, 'slow_period': 22, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.001678738397221493, 'take_profit': 0.020522040894711213, 'position_size': 0.37141283523262447}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_33', 'SMA_49', 'RSI_13']
# [I 2025-10-05 14:59:10,654] Trial 93 finished with value: 0.0 and parameters: {'SMA_short_period': 33, 'SMA_long_period': 49, 'RSI_period': 13, 'BollingerBands_period': 20, 'BollingerBands_std_dev': 1.6054417577354962, 'MACD_fast_period': 9, 'MACD_slow_period': 22, 'MACD_signal_period': 12, 'stop_loss': 0.001678738397221493, 'take_profit': 0.020522040894711213, 'position_size': 0.37141283523262447}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f0936150>, <financeta.utils.ta.SMA object at 0x7f07c9190110>, <financeta.utils.ta.RSI object at 0x7f07c9193950>, <financeta.utils.ta.BollingerBands object at 0x7f07c91dc250>, <financeta.utils.ta.MACD object at 0x7f07c91dc350>]
#
# Trial 94:
#   Indicators: {'SMA_short': {'period': 10}, 'SMA_long': {'period': 164}, 'RSI': {'period': 21}, 'BollingerBands': {'period': 10, 'std_dev': 2.293499323207874}, 'MACD': {'fast_period': 9, 'slow_period': 26, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.00132814617205786, 'take_profit': 0.014023914114236678, 'position_size': 0.5601818683053561}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_10', 'SMA_164', 'RSI_21']
# [I 2025-10-05 14:59:10,683] Trial 94 finished with value: 0.0 and parameters: {'SMA_short_period': 10, 'SMA_long_period': 164, 'RSI_period': 21, 'BollingerBands_period': 10, 'BollingerBands_std_dev': 2.293499323207874, 'MACD_fast_period': 9, 'MACD_slow_period': 26, 'MACD_signal_period': 11, 'stop_loss': 0.00132814617205786, 'take_profit': 0.014023914114236678, 'position_size': 0.5601818683053561}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2dbcdd0>, <financeta.utils.ta.SMA object at 0x7f07c91dcc90>, <financeta.utils.ta.RSI object at 0x7f07c91dc050>, <financeta.utils.ta.BollingerBands object at 0x7f07c91dc910>, <financeta.utils.ta.MACD object at 0x7f07c91dcc50>]
#
# Trial 95:
#   Indicators: {'SMA_short': {'period': 22}, 'SMA_long': {'period': 188}, 'RSI': {'period': 18}, 'BollingerBands': {'period': 27, 'std_dev': 1.7070518867776334}, 'MACD': {'fast_period': 8, 'slow_period': 23, 'signal_period': 11}}
#   Strategy: {'stop_loss': 0.005938523470315473, 'take_profit': 0.04098590322443034, 'position_size': 0.4277733046983064}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_22', 'SMA_188', 'RSI_18']
# [I 2025-10-05 14:59:10,709] Trial 95 finished with value: 0.0 and parameters: {'SMA_short_period': 22, 'SMA_long_period': 188, 'RSI_period': 18, 'BollingerBands_period': 27, 'BollingerBands_std_dev': 1.7070518867776334, 'MACD_fast_period': 8, 'MACD_slow_period': 23, 'MACD_signal_period': 11, 'stop_loss': 0.005938523470315473, 'take_profit': 0.04098590322443034, 'position_size': 0.4277733046983064}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07914054d0>, <financeta.utils.ta.SMA object at 0x7f07c91dd890>, <financeta.utils.ta.RSI object at 0x7f07c91dd9d0>, <financeta.utils.ta.BollingerBands object at 0x7f07c91dd990>, <financeta.utils.ta.MACD object at 0x7f07c91dd850>]
#
# Trial 96:
#   Indicators: {'SMA_short': {'period': 17}, 'SMA_long': {'period': 183}, 'RSI': {'period': 16}, 'BollingerBands': {'period': 22, 'std_dev': 1.5040970140931278}, 'MACD': {'fast_period': 12, 'slow_period': 24, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.005052303761686503, 'take_profit': 0.007689809734191097, 'position_size': 0.17069733845940238}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_17', 'SMA_183', 'RSI_16']
# [I 2025-10-05 14:59:10,740] Trial 96 finished with value: 0.0 and parameters: {'SMA_short_period': 17, 'SMA_long_period': 183, 'RSI_period': 16, 'BollingerBands_period': 22, 'BollingerBands_std_dev': 1.5040970140931278, 'MACD_fast_period': 12, 'MACD_slow_period': 24, 'MACD_signal_period': 12, 'stop_loss': 0.005052303761686503, 'take_profit': 0.007689809734191097, 'position_size': 0.17069733845940238}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2b84f90>, <financeta.utils.ta.SMA object at 0x7f07f2dbc690>, <financeta.utils.ta.RSI object at 0x7f07bb8e4290>, <financeta.utils.ta.BollingerBands object at 0x7f07c91de590>, <financeta.utils.ta.MACD object at 0x7f07c91de410>]
#
# Trial 97:
#   Indicators: {'SMA_short': {'period': 12}, 'SMA_long': {'period': 58}, 'RSI': {'period': 17}, 'BollingerBands': {'period': 28, 'std_dev': 1.5623921390040205}, 'MACD': {'fast_period': 12, 'slow_period': 20, 'signal_period': 7}}
#   Strategy: {'stop_loss': 0.020928132752522803, 'take_profit': 0.028019942979706006, 'position_size': 0.45815582067138394}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_12', 'SMA_58', 'RSI_17']
# [I 2025-10-05 14:59:10,774] Trial 97 finished with value: 0.0 and parameters: {'SMA_short_period': 12, 'SMA_long_period': 58, 'RSI_period': 17, 'BollingerBands_period': 28, 'BollingerBands_std_dev': 1.5623921390040205, 'MACD_fast_period': 12, 'MACD_slow_period': 20, 'MACD_signal_period': 7, 'stop_loss': 0.020928132752522803, 'take_profit': 0.028019942979706006, 'position_size': 0.45815582067138394}. Best is trial 0 with value: 0.0.
# Best trial: 0. Best value: 0: 100%|██████████| 100/100 [00:02<00:00, 35.64it/s, 2.80/3600 seconds]
# [<financeta.utils.ta.SMA object at 0x7f07c918f190>, <financeta.utils.ta.SMA object at 0x7f07914053d0>, <financeta.utils.ta.RSI object at 0x7f07c91df0d0>, <financeta.utils.ta.BollingerBands object at 0x7f07c91df150>, <financeta.utils.ta.MACD object at 0x7f07c91df350>]
#
# Trial 98:
#   Indicators: {'SMA_short': {'period': 20}, 'SMA_long': {'period': 174}, 'RSI': {'period': 20}, 'BollingerBands': {'period': 19, 'std_dev': 2.0921666176259377}, 'MACD': {'fast_period': 10, 'slow_period': 25, 'signal_period': 10}}
#   Strategy: {'stop_loss': 0.0012513622766875047, 'take_profit': 0.0048511141346914135, 'position_size': 0.11725601325805615}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_20', 'SMA_174', 'RSI_20']
# [I 2025-10-05 14:59:10,809] Trial 98 finished with value: 0.0 and parameters: {'SMA_short_period': 20, 'SMA_long_period': 174, 'RSI_period': 20, 'BollingerBands_period': 19, 'BollingerBands_std_dev': 2.0921666176259377, 'MACD_fast_period': 10, 'MACD_slow_period': 25, 'MACD_signal_period': 10, 'stop_loss': 0.0012513622766875047, 'take_profit': 0.0048511141346914135, 'position_size': 0.11725601325805615}. Best is trial 0 with value: 0.0.
# [<financeta.utils.ta.SMA object at 0x7f07f2c91350>, <financeta.utils.ta.SMA object at 0x7f07c918f0d0>, <financeta.utils.ta.RSI object at 0x7f07f2187cd0>, <financeta.utils.ta.BollingerBands object at 0x7f07c91df3d0>, <financeta.utils.ta.MACD object at 0x7f07c91dfe10>]
#
# Trial 99:
#   Indicators: {'SMA_short': {'period': 14}, 'SMA_long': {'period': 101}, 'RSI': {'period': 8}, 'BollingerBands': {'period': 16, 'std_dev': 1.6354252887559295}, 'MACD': {'fast_period': 11, 'slow_period': 23, 'signal_period': 12}}
#   Strategy: {'stop_loss': 0.008255531698034621, 'take_profit': 0.0013628828205722399, 'position_size': 0.9775845982067155}
# Erreur dans backtest_strategy: Colonnes manquantes: ['SMA_14', 'SMA_101', 'RSI_8']
# [I 2025-10-05 14:59:10,842] Trial 99 finished with value: 0.0 and parameters: {'SMA_short_period': 14, 'SMA_long_period': 101, 'RSI_period': 8, 'BollingerBands_period': 16, 'BollingerBands_std_dev': 1.6354252887559295, 'MACD_fast_period': 11, 'MACD_slow_period': 23, 'MACD_signal_period': 12, 'stop_loss': 0.008255531698034621, 'take_profit': 0.0013628828205722399, 'position_size': 0.9775845982067155}. Best is trial 0 with value: 0.0.
#
# ======================================================================
# RÉSULTATS DE L'OPTIMISATION
# ======================================================================
#
# 🏆 Meilleur Sharpe Ratio: 0.0000
#
# 📊 Meilleurs paramètres:
#
#   Indicateurs:
#     SMA_short_period: 22
#     SMA_long_period: 192
#     RSI_period: 17
#     BollingerBands_period: 22
#     BollingerBands_std_dev: 1.7340279606636548
#     MACD_fast_period: 9
#     MACD_slow_period: 20
#     MACD_signal_period: 12
#
#   Stratégie:
#     stop_loss: 0.010502105436744277
#     take_profit: 0.01595857358814127
#     position_size: 0.1185260448662222
#
# 💰 Métriques de performance:
#     Total Return: 0.0000
#     CAGR: 0.0000
#     Max Drawdown: 0.0000
#
# ✅ Meilleure configuration sauvegardée dans 'best_config.json'

# %%
best_config
# Out:
# {'indicators': {'SMA_short': {'period': 22},
#   'SMA_long': {'period': 192},
#   'RSI': {'period': 17},
#   'BollingerBands': {'period': 22, 'std_dev': 1.7340279606636548},
#   'MACD': {'fast_period': 9, 'slow_period': 20, 'signal_period': 12}},
#  'strategy': {'stop_loss': 0.010502105436744277,
#   'take_profit': 0.01595857358814127,
#   'position_size': 0.1185260448662222}}

# %%
# crée un plot avec les meilleurs paramètres
best_indicators = create_indicators_from_params(OPTIMIZATION_CONFIG, {
    'indicators': best_config['indicators'],
    'strategy': best_config['strategy']
})
traces = [
    Candlesticks(),
    Line('hl_avg', name='HL Average', color='purple'),
    Volume()
]
chart_client.plot(df, "AAPL - Best Config", traces=traces, indicators=best_indicators, theme='professional')
